# %%
import pandas as pd 
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

# %%
df = pd.read_csv('topalbums_lyrics_deleted_nonlyrics_category.csv')
df.head()
# Out:
#    Unnamed: 0  index  album_index        artist  year  \
# 0           0      0            0  Taylor Swift  2014
# 1           1      1            0  Taylor Swift  2014
# 2           2      2            0  Taylor Swift  2014
# 3           3      3            0  Taylor Swift  2014
# 4           4      4            0  Taylor Swift  2014
#
#                                    title_song title_album  \
# 0         Welcome to New York by Taylor Swift        1989
# 1                 Blank Space by Taylor Swift        1989
# 2                       Style by Taylor Swift        1989
# 3            Out of the Woods by Taylor Swift        1989
# 4  All You Had to Do Was Stay by Taylor Swift        1989
#
#                                               lyrics  pageviews  \
# 0  [Verse 1]\nWalking through a crowd, the villag...   208419.0
# 1  [Verse 1]\nNice to meet you, where you been?\n...  1415048.0
# 2  [Verse 1]\nMidnight\nYou come and pick me up, ...  1057744.0
# 3  [Verse 1]\nLooking at it now\nIt all seems so ...   425911.0
# 4  [Intro]\n(Hey, hey, hey)\n(Hey, hey, hey)\n(He...   227084.0
#
#    contributed_times  ...  sanctity_p  care_sent  fairness_sent  loyalty_sent  \
# 0               11.0  ...    0.102123   0.077717       0.137289      0.183210
# 1               22.0  ...    0.099068  -0.010199       0.014044      0.040366
# 2               17.0  ...    0.075140  -0.084347       0.006298      0.047535
# 3               15.0  ...    0.052627   0.053325       0.181610      0.117266
# 4               10.0  ...    0.095183   0.009514       0.088668      0.148867
#
#    authority_sent  sanctity_sent  moral_nonmoral_ratio     f_var  sent_var  \
# 0        0.157467       0.083834              1.935484  0.000495  0.002120
# 1        0.021655       0.042042              1.048780  0.000223  0.000460
# 2        0.022957      -0.006237              1.507692  0.000106  0.002485
# 3        0.083112       0.044965              3.605263  0.000268  0.003093
# 4        0.047225       0.121170              1.466667  0.000199  0.003127
#
#    category
# 0   not_rap
# 1   not_rap
# 2   not_rap
# 3   not_rap
# 4   not_rap
#
# [5 rows x 25 columns]

# %%
df['title_song'].value_counts()
# Out:
# O'Lord by Lauren Daigle                            3
# 24K Magic by Bruno Mars                            3
# Sugar by Maroon 5                                  3
# \nIntro                                            3
# Love Yourself by Justin Bieber                     3
#                                                   ..
# \nWaiting in Vain                                  1
# Legend of the Fall Offs by Busta Rhymes            1
# All I Want for Christmas Is You by Idina Menzel    1
# Delicious by A Perfect Circle                      1
# And So It Goes by Jordan Smith                     1
# Name: title_song, Length: 11488, dtype: int64

# %%
# slicing columns
df.iloc[ :,1:5]
# Out:
#        index  album_index        artist  year
# 0          0            0  Taylor Swift  2014
# 1          1            0  Taylor Swift  2014
# 2          2            0  Taylor Swift  2014
# 3          3            0  Taylor Swift  2014
# 4          4            0  Taylor Swift  2014
# ...      ...          ...           ...   ...
# 11700  12040          889  Pooh Shiesty  2021
# 11701  12041          889  Pooh Shiesty  2021
# 11702  12042          889  Pooh Shiesty  2021
# 11703  12043          889  Pooh Shiesty  2021
# 11704  12044          889  Pooh Shiesty  2021
#
# [11705 rows x 4 columns]

# %%
# sort all the data by year
yearsort= df.sort_values("year", ascending=True)
yearsort
# Out:
#        Unnamed: 0  index  album_index         artist  year  \
# 3892         3892   4098          304    The Beatles  1968
# 3883         3883   4089          304    The Beatles  1968
# 3884         3884   4090          304    The Beatles  1968
# 3885         3885   4091          304    The Beatles  1968
# 3886         3886   4092          304    The Beatles  1968
# ...           ...    ...          ...            ...   ...
# 5251         5251   5494          415  Morgan Wallen  2021
# 10627       10627  10961          795         Polo G  2021
# 10626       10626  10960          795         Polo G  2021
# 10592       10592  10926          793     Kanye West  2021
# 11704       11704  12044          889   Pooh Shiesty  2021
#
#                                               title_song  \
# 3892                              Piggies by The Beatles
# 3883                          Glass Onion by The Beatles
# 3884                   Ob-La-Di, Ob-La-Da by The Beatles
# 3885                       Wild Honey Pie by The Beatles
# 3886   The Continuing Story of Bungalow Bill by The B...
# ...                                                  ...
# 5251                        Cover Me Up by Morgan Wallen
# 10627                            Bloody Canvas by Polo G
# 10626  Clueless by Polo G (Ft. Fivio Foreign & Pop Sm...
# 10592      Remote Control by Kanye West (Ft. Young Thug)
# 11704                                         \nTwerksum
#
#                        title_album  \
# 3892     The Beatles [White Album]
# 3883     The Beatles [White Album]
# 3884     The Beatles [White Album]
# 3885     The Beatles [White Album]
# 3886     The Beatles [White Album]
# ...                            ...
# 5251   Dangerous: The Double Album
# 10627                 Hall Of Fame
# 10626                 Hall Of Fame
# 10592                        Donda
# 11704               Shiesty Season
#
#                                                   lyrics  pageviews  \
# 3892   [Verse 1]\nHave you seen the little piggies cr...    64463.0
# 3883   [Verse 1]\nI told you 'bout Strawberry Fields\...    83961.0
# 3884   [Verse 1]\nDesmond has a barrow in the market ...   289940.0
# 3885   [Chorus]\nHoney pie\nHoney pie\n\n[Chorus]\nHo...    20146.0
# 3886   [Chorus]\nHey, Bungalow Bill\nWhat did you kil...    58114.0
# ...                                                  ...        ...
# 5251   [Verse 1]\nA heart on a run keeps a hand on a ...   112890.0
# 10627  [Intro]\nHead's burnin', wasn't told\nTo leave...   126021.0
# 10626  [Intro: Pop Smoke]\n(AXL)\nLook, woo\n\n[Choru...   191070.0
# 10592  [Intro: Kanye West]\nPlease don't ask again, w...   496414.0
# 11704  [Intro]\n(Jordan produced it)\nMmm-mmm-mmm\nBl...        NaN
#
#        contributed_times  ...  sanctity_p  care_sent  fairness_sent  \
# 3892                 6.0  ...    0.101537   0.036703       0.079881
# 3883                17.0  ...    0.075442  -0.031223      -0.000417
# 3884                 8.0  ...    0.083805  -0.087527       0.072398
# 3885                 1.0  ...    0.145455   0.587559       0.528279
# 3886                 9.0  ...    0.144361  -0.379482      -0.418788
# ...                  ...  ...         ...        ...            ...
# 5251                 1.0  ...    0.098306  -0.044614       0.019031
# 10627                6.0  ...    0.088631  -0.128922      -0.068284
# 10626                6.0  ...    0.094728  -0.070330      -0.015189
# 10592               13.0  ...    0.082726  -0.093397      -0.062464
# 11704                NaN  ...    0.083302  -0.047570       0.012723
#
#        loyalty_sent  authority_sent  sanctity_sent  moral_nonmoral_ratio  \
# 3892       0.170030        0.046866       0.118380              0.527778
# 3883      -0.044748       -0.037332      -0.062883              0.772727
# 3884       0.133085       -0.017247       0.111063              0.525000
# 3885       0.610869        0.656585       0.577225              0.043478
# 3886      -0.291481       -0.344882      -0.385699              0.513514
# ...             ...             ...            ...                   ...
# 5251       0.021102       -0.002121       0.002408              1.172414
# 10627     -0.006321       -0.057174      -0.074284              0.892562
# 10626      0.026675       -0.013740      -0.005926              0.406143
# 10592      0.025051        0.052838       0.026021              0.786260
# 11704      0.021134        0.014046      -0.013453              0.764706
#
#           f_var  sent_var  category
# 3892   0.000107  0.003003   not_rap
# 3883   0.000178  0.000522   not_rap
# 3884   0.000167  0.008569   not_rap
# 3885   0.003910  0.002206   not_rap
# 3886   0.002204  0.002334   not_rap
# ...         ...       ...       ...
# 5251   0.000200  0.000701   not_rap
# 10627  0.000159  0.001917       rap
# 10626  0.000042  0.001220       rap
# 10592  0.000114  0.004045       rap
# 11704  0.000149  0.000804       rap
#
# [11705 rows x 25 columns]

# %%
# testing the first 100 data, see the changes on sanctity_p (col15) by time (col4)
year_test=yearsort["year"]
sanctity_p_test=yearsort["sanctity_p"]

plt.plot(year_test, sanctity_p_test)
plt.title('sanctity_p Vs Year')
plt.xlabel('Year')
plt.ylabel('sanctity_p')
plt.show()
figure(figsize=(8, 10), dpi=800)

# %%
# seperate all df based on type "non_rap" and "rap"
# non_rap 6236 songs
#rap_type=df.iloc[1:11706,24]
rap_type=df["category"]
grouped = df.groupby(rap_type)
listby_not_rap = grouped.get_group("not_rap")
listby_not_rap
# Out:
#        Unnamed: 0  index  album_index        artist  year  \
# 0               0      0            0  Taylor Swift  2014
# 1               1      1            0  Taylor Swift  2014
# 2               2      2            0  Taylor Swift  2014
# 3               3      3            0  Taylor Swift  2014
# 4               4      4            0  Taylor Swift  2014
# ...           ...    ...          ...           ...   ...
# 11118       11118  11453          838   The Beatles  2021
# 11119       11119  11454          838   The Beatles  2021
# 11120       11120  11455          838   The Beatles  2021
# 11121       11121  11456          838   The Beatles  2021
# 11122       11122  11457          838   The Beatles  2021
#
#                                        title_song             title_album  \
# 0             Welcome to New York by Taylor Swift                    1989
# 1                     Blank Space by Taylor Swift                    1989
# 2                           Style by Taylor Swift                    1989
# 3                Out of the Woods by Taylor Swift                    1989
# 4      All You Had to Do Was Stay by Taylor Swift                    1989
# ...                                           ...                     ...
# 11118    \nI've Got a Feeling (Ft. Billy Preston)  Let It Be (Soundtrack)
# 11119                             \nOne After 909  Let It Be (Soundtrack)
# 11120                 \nThe Long and Winding Road  Let It Be (Soundtrack)
# 11121                              \nFor You Blue  Let It Be (Soundtrack)
# 11122             \nGet Back (Ft. Billy Preston)   Let It Be (Soundtrack)
#
#                                                   lyrics  pageviews  \
# 0      [Verse 1]\nWalking through a crowd, the villag...   208419.0
# 1      [Verse 1]\nNice to meet you, where you been?\n...  1415048.0
# 2      [Verse 1]\nMidnight\nYou come and pick me up, ...  1057744.0
# 3      [Verse 1]\nLooking at it now\nIt all seems so ...   425911.0
# 4      [Intro]\n(Hey, hey, hey)\n(Hey, hey, hey)\n(He...   227084.0
# ...                                                  ...        ...
# 11118  [Verse 1: Paul McCartney]\nI've got a feeling,...        NaN
# 11119  [Verse 1]\nMy baby said she's traveling on the...        NaN
# 11120  [Verse 1]\nThe long and winding road that lead...        NaN
# 11121  [Intro]\n(Queen says no to pot-smoking FBI mem...        NaN
# 11122  [Intro: Paul McCartney & John Lennon]\nRosetta...        NaN
#
#        contributed_times  ...  sanctity_p  care_sent  fairness_sent  \
# 0                   11.0  ...    0.102123   0.077717       0.137289
# 1                   22.0  ...    0.099068  -0.010199       0.014044
# 2                   17.0  ...    0.075140  -0.084347       0.006298
# 3                   15.0  ...    0.052627   0.053325       0.181610
# 4                   10.0  ...    0.095183   0.009514       0.088668
# ...                  ...  ...         ...        ...            ...
# 11118                NaN  ...    0.111416   0.034573      -0.005361
# 11119                NaN  ...    0.085649  -0.160487      -0.010658
# 11120                NaN  ...    0.073723  -0.101598      -0.064927
# 11121                NaN  ...    0.116951   0.005196       0.188555
# 11122                NaN  ...    0.080381  -0.091088       0.068576
#
#        loyalty_sent  authority_sent  sanctity_sent  moral_nonmoral_ratio  \
# 0          0.183210        0.157467       0.083834              1.935484
# 1          0.040366        0.021655       0.042042              1.048780
# 2          0.047535        0.022957      -0.006237              1.507692
# 3          0.117266        0.083112       0.044965              3.605263
# 4          0.148867        0.047225       0.121170              1.466667
# ...             ...             ...            ...                   ...
# 11118      0.056925        0.061867       0.038987              0.692913
# 11119     -0.001807       -0.079999      -0.062762              4.333333
# 11120     -0.037870       -0.053852      -0.124799              2.041667
# 11121      0.061540        0.160945       0.145413              1.250000
# 11122      0.013566        0.006729      -0.075466              0.279070
#
#           f_var  sent_var  category
# 0      0.000495  0.002120   not_rap
# 1      0.000223  0.000460   not_rap
# 2      0.000106  0.002485   not_rap
# 3      0.000268  0.003093   not_rap
# 4      0.000199  0.003127   not_rap
# ...         ...       ...       ...
# 11118  0.000421  0.000705   not_rap
# 11119  0.000548  0.004069   not_rap
# 11120  0.000278  0.001275   not_rap
# 11121  0.000518  0.005831   not_rap
# 11122  0.000084  0.004429   not_rap
#
# [6236 rows x 25 columns]

# %%
listby_not_rap.describe()
# Out:
#          Unnamed: 0         index  album_index         year     pageviews  \
# count   6236.000000   6236.000000  6236.000000  6236.000000  4.440000e+03
# mean    3505.708948   3674.830821   274.378287  2014.880212  2.960281e+05
# std     2686.146838   2768.216761   201.001303     8.290704  7.948226e+05
# min        0.000000      0.000000     0.000000  1968.000000  5.000000e+03
# 25%     1558.750000   1662.750000   132.000000  2015.000000  2.101400e+04
# 50%     3117.500000   3299.500000   243.000000  2017.000000  7.215200e+04
# 75%     4676.250000   4916.250000   366.000000  2019.000000  2.512298e+05
# max    11122.000000  11457.000000   838.000000  2021.000000  2.331799e+07
#
#        contributed_times       index.1       care_p   fairness_p    loyalty_p  \
# count        5770.000000   6236.000000  6236.000000  6236.000000  6236.000000
# mean            5.158059   3506.708948     0.112386     0.094494     0.095889
# std             7.839235   2686.146838     0.024850     0.019889     0.019101
# min             0.000000      1.000000     0.000000     0.000000     0.000000
# 25%             1.000000   1559.750000     0.101043     0.086335     0.088234
# 50%             2.000000   3118.500000     0.111941     0.094960     0.096183
# 75%             7.000000   4677.250000     0.124299     0.103821     0.104743
# max           178.000000  11123.000000     0.322581     0.249119     0.238016
#
#        authority_p   sanctity_p    care_sent  fairness_sent  loyalty_sent  \
# count  6236.000000  6236.000000  6236.000000    6236.000000   6236.000000
# mean      0.085324     0.091753    -0.047507       0.003030      0.031764
# std       0.017513     0.019116     0.091527       0.086652      0.084739
# min       0.000000     0.000000    -0.712507      -0.711506     -0.746692
# 25%       0.078031     0.083610    -0.100376      -0.044961     -0.013671
# 50%       0.085707     0.092093    -0.053598       0.000000      0.027182
# 75%       0.093934     0.100920    -0.001516       0.046446      0.072441
# max       0.217970     0.241781     0.610135       0.637461      0.622767
#
#        authority_sent  sanctity_sent  moral_nonmoral_ratio        f_var  \
# count     6236.000000    6236.000000           6236.000000  6236.000000
# mean         0.006160      -0.012232              1.127441     0.000248
# std          0.094524       0.088819              0.750904     0.000351
# min         -0.733595      -0.756873              0.000000     0.000000
# 25%         -0.045586      -0.062738              0.666667     0.000088
# 50%          0.000000      -0.016570              1.000000     0.000154
# 75%          0.052787       0.032567              1.422300     0.000285
# max          0.691975       0.664900             17.000000     0.006600
#
#           sent_var
# count  6236.000000
# mean      0.002528
# std       0.003882
# min       0.000000
# 25%       0.000944
# 50%       0.001674
# 75%       0.002805
# max       0.096377

# %%
# rap 5432 songs
#rap_type=df.iloc[1:11706,24]
rap_type=df["category"]
grouped = df.groupby(rap_type)
listby_rap = grouped.get_group("rap")
listby_rap
# Out:
#        Unnamed: 0  index  album_index        artist  year  \
# 5755         5755   6010          458     Lil Wayne  2005
# 5756         5756   6011          458     Lil Wayne  2005
# 5757         5757   6012          458     Lil Wayne  2005
# 5758         5758   6013          458     Lil Wayne  2005
# 5759         5759   6014          458     Lil Wayne  2005
# ...           ...    ...          ...           ...   ...
# 11700       11700  12040          889  Pooh Shiesty  2021
# 11701       11701  12041          889  Pooh Shiesty  2021
# 11702       11702  12042          889  Pooh Shiesty  2021
# 11703       11703  12043          889  Pooh Shiesty  2021
# 11704       11704  12044          889  Pooh Shiesty  2021
#
#                                        title_song     title_album  \
# 5755                        Tha Mobb by Lil Wayne   Tha Carter II
# 5756                          Fly In by Lil Wayne   Tha Carter II
# 5757                Money On My Mind by Lil Wayne   Tha Carter II
# 5758                         Fireman by Lil Wayne   Tha Carter II
# 5759                         Mo Fire by Lil Wayne   Tha Carter II
# ...                                           ...             ...
# 11700  \nBig 13 Gang (Ft. Choppa Wop & Lil Hank)   Shiesty Season
# 11701                            \nDrop Some Shit  Shiesty Season
# 11702                                  \nSee Red   Shiesty Season
# 11703                  \nMaster P (Ft. Tay Keith)  Shiesty Season
# 11704                                  \nTwerksum  Shiesty Season
#
#                                                   lyrics  pageviews  \
# 5755   [Intro]\nYeah\nHardbody, hardbody\nCarter, Car...    89120.0
# 5756   [Intro]\nSo they ask me\n"Young boy\nWhat you ...    77064.0
# 5757   [Intro]\nYeah\nMoney on my mind, money on my m...   126743.0
# 5758   [Intro]\n(Weezy Baby)\nShh, the fireman comin'...   145269.0
# 5759   [Intro]\nMo' fire, Weezy\nMo' fire (Put yuh li...    25642.0
# ...                                                  ...        ...
# 11700  [Intro: Pooh Shiesty]\nBlrrrd, blrrrd, blrrrd\...        NaN
# 11701  [Intro]\nCook it up, Dre\nUh, uh, ah\nHey, I'm...        NaN
# 11702  [Intro]\nAnd we all wanna be somethin' (Blrrrd...        NaN
# 11703  [Intro]\nTay Keith, fuck these niggas up\nDamn...        NaN
# 11704  [Intro]\n(Jordan produced it)\nMmm-mmm-mmm\nBl...        NaN
#
#        contributed_times  ...  sanctity_p  care_sent  fairness_sent  \
# 5755                15.0  ...    0.093408  -0.065639      -0.040022
# 5756                19.0  ...    0.090983  -0.103180      -0.050820
# 5757                13.0  ...    0.103673  -0.059483      -0.014666
# 5758                15.0  ...    0.092140  -0.056582      -0.033719
# 5759                 6.0  ...    0.085316  -0.064709      -0.003570
# ...                  ...  ...         ...        ...            ...
# 11700                NaN  ...    0.112583  -0.141807      -0.091797
# 11701                NaN  ...    0.096513  -0.123812      -0.096298
# 11702                NaN  ...    0.098229  -0.127752      -0.057028
# 11703                NaN  ...    0.099089  -0.038912       0.050672
# 11704                NaN  ...    0.083302  -0.047570       0.012723
#
#        loyalty_sent  authority_sent  sanctity_sent  moral_nonmoral_ratio  \
# 5755      -0.013976       -0.044037      -0.043396              0.612676
# 5756      -0.008905       -0.031218      -0.053843              0.762712
# 5757       0.039948       -0.021713      -0.028316              0.732673
# 5758       0.021562       -0.032383      -0.025109              0.515504
# 5759       0.019600       -0.005131      -0.032468              0.535211
# ...             ...             ...            ...                   ...
# 11700     -0.053513       -0.058785      -0.095439              0.750000
# 11701     -0.076960       -0.091817      -0.119634              0.647059
# 11702     -0.042653       -0.053209      -0.074860              0.762332
# 11703      0.115025        0.100912       0.038552              0.785088
# 11704      0.021134        0.014046      -0.013453              0.764706
#
#           f_var  sent_var  category
# 5755   0.000161  0.000338       rap
# 5756   0.000156  0.001221       rap
# 5757   0.000312  0.001301       rap
# 5758   0.000133  0.000824       rap
# 5759   0.000167  0.001044       rap
# ...         ...       ...       ...
# 11700  0.000284  0.001252       rap
# 11701  0.000091  0.000387       rap
# 11702  0.000271  0.001138       rap
# 11703  0.000138  0.003701       rap
# 11704  0.000149  0.000804       rap
#
# [5432 rows x 25 columns]

# %%
listby_rap.describe()
# Out:
#          Unnamed: 0         index  album_index         year     pageviews  \
# count   5432.000000   5432.000000  5432.000000  5432.000000  3.945000e+03
# mean    8529.340758   8841.141200   649.161267  2012.356775  3.931193e+05
# std     1662.995933   1689.270581   119.577405     4.612604  8.651702e+05
# min     5755.000000   6010.000000   458.000000  2003.000000  5.010000e+03
# 25%     7112.750000   7391.750000   545.000000  2009.000000  3.149000e+04
# 50%     8470.500000   8800.500000   646.000000  2012.000000  1.031630e+05
# 75%     9851.250000  10184.250000   737.000000  2016.000000  3.522320e+05
# max    11704.000000  12044.000000   889.000000  2021.000000  1.743397e+07
#
#        contributed_times       index.1       care_p   fairness_p    loyalty_p  \
# count        4850.000000   5432.000000  5432.000000  5432.000000  5432.000000
# mean           11.443505   8530.340758     0.112962     0.097702     0.092740
# std            11.593541   1662.995933     0.017478     0.014086     0.012538
# min             0.000000   5756.000000     0.000000     0.000000     0.000000
# 25%             3.000000   7113.750000     0.104278     0.090846     0.086982
# 50%             8.000000   8471.500000     0.112204     0.097520     0.092857
# 75%            17.000000   9852.250000     0.121107     0.104728     0.098911
# max           111.000000  11705.000000     0.294020     0.272389     0.175759
#
#        authority_p   sanctity_p    care_sent  fairness_sent  loyalty_sent  \
# count  5432.000000  5432.000000  5432.000000    5432.000000   5432.000000
# mean      0.087267     0.092324    -0.069860      -0.010428      0.012712
# std       0.012640     0.013621     0.062689       0.060496      0.058626
# min       0.000000     0.000000    -0.559882      -0.596188     -0.606028
# 25%       0.081130     0.085628    -0.102869      -0.043385     -0.018323
# 50%       0.087102     0.091948    -0.071007      -0.010440      0.012387
# 75%       0.093070     0.098640    -0.038853       0.022520      0.043335
# max       0.203473     0.215398     0.765000       0.670200      0.610869
#
#        authority_sent  sanctity_sent  moral_nonmoral_ratio        f_var  \
# count     5432.000000    5432.000000           5432.000000  5432.000000
# mean        -0.011193      -0.030732              0.819663     0.000185
# std          0.064200       0.059964              0.398581     0.000291
# min         -0.454081      -0.514470              0.000000     0.000000
# 25%         -0.045871      -0.063615              0.571944     0.000080
# 50%         -0.010711      -0.030643              0.748780     0.000128
# 75%          0.020830       0.000974              0.974359     0.000205
# max          0.664100       0.577225              6.636364     0.009797
#
#           sent_var
# count  5432.000000
# mean      0.001874
# std       0.002649
# min       0.000000
# 25%       0.000893
# 50%       0.001383
# 75%       0.002109
# max       0.105174

# %%
listby_not_rap.describe()
# Out:
#          Unnamed: 0         index  album_index         year     pageviews  \
# count   6236.000000   6236.000000  6236.000000  6236.000000  4.440000e+03
# mean    3505.708948   3674.830821   274.378287  2014.880212  2.960281e+05
# std     2686.146838   2768.216761   201.001303     8.290704  7.948226e+05
# min        0.000000      0.000000     0.000000  1968.000000  5.000000e+03
# 25%     1558.750000   1662.750000   132.000000  2015.000000  2.101400e+04
# 50%     3117.500000   3299.500000   243.000000  2017.000000  7.215200e+04
# 75%     4676.250000   4916.250000   366.000000  2019.000000  2.512298e+05
# max    11122.000000  11457.000000   838.000000  2021.000000  2.331799e+07
#
#        contributed_times       index.1       care_p   fairness_p    loyalty_p  \
# count        5770.000000   6236.000000  6236.000000  6236.000000  6236.000000
# mean            5.158059   3506.708948     0.112386     0.094494     0.095889
# std             7.839235   2686.146838     0.024850     0.019889     0.019101
# min             0.000000      1.000000     0.000000     0.000000     0.000000
# 25%             1.000000   1559.750000     0.101043     0.086335     0.088234
# 50%             2.000000   3118.500000     0.111941     0.094960     0.096183
# 75%             7.000000   4677.250000     0.124299     0.103821     0.104743
# max           178.000000  11123.000000     0.322581     0.249119     0.238016
#
#        authority_p   sanctity_p    care_sent  fairness_sent  loyalty_sent  \
# count  6236.000000  6236.000000  6236.000000    6236.000000   6236.000000
# mean      0.085324     0.091753    -0.047507       0.003030      0.031764
# std       0.017513     0.019116     0.091527       0.086652      0.084739
# min       0.000000     0.000000    -0.712507      -0.711506     -0.746692
# 25%       0.078031     0.083610    -0.100376      -0.044961     -0.013671
# 50%       0.085707     0.092093    -0.053598       0.000000      0.027182
# 75%       0.093934     0.100920    -0.001516       0.046446      0.072441
# max       0.217970     0.241781     0.610135       0.637461      0.622767
#
#        authority_sent  sanctity_sent  moral_nonmoral_ratio        f_var  \
# count     6236.000000    6236.000000           6236.000000  6236.000000
# mean         0.006160      -0.012232              1.127441     0.000248
# std          0.094524       0.088819              0.750904     0.000351
# min         -0.733595      -0.756873              0.000000     0.000000
# 25%         -0.045586      -0.062738              0.666667     0.000088
# 50%          0.000000      -0.016570              1.000000     0.000154
# 75%          0.052787       0.032567              1.422300     0.000285
# max          0.691975       0.664900             17.000000     0.006600
#
#           sent_var
# count  6236.000000
# mean      0.002528
# std       0.003882
# min       0.000000
# 25%       0.000944
# 50%       0.001674
# 75%       0.002805
# max       0.096377

# %%
# draw 3 line chart on moral_nonmoral_ratio,authority_sent,fairness_p, to year for both rap and non rap
# line chart for moral_nonmoral_ratio for rap
# result--> maybe there this a increase in "moral_nonmoral_ratio", try scatter plot
year_test_rap=listby_rap.iloc[1:5432 :,4]
moral_nonmoral_ratio_test_rap=listby_rap.iloc[1:5432:,21]

plt.plot(year_test_rap, moral_nonmoral_ratio_test_rap)
plt.title('moral_nonmoral_ratio for rap Vs Year')
plt.xlabel('Year')
plt.ylabel('moral_nonmoral_ratio')
plt.show()
figure(figsize=(8, 100), dpi=800)

# %%
year_test_rap=listby_rap["year"][4000:5432]
moral_nonmoral_ratio_test_rap=listby_rap["moral_nonmoral_ratio"][4000:5432]

plt.plot(year_test_rap, moral_nonmoral_ratio_test_rap)
plt.title('moral_nonmoral_ratio for rap Vs Year')
plt.xlabel('Year')
plt.ylabel('moral_nonmoral_ratio')
plt.show()
figure(figsize=(8, 100), dpi=800)

# %%
year_test_rap=listby_rap["year"][4000:5432]
moral_nonmoral_ratio_test_rap=listby_rap["moral_nonmoral_ratio"][4000:5432]

plt.scatter(year_test_rap, moral_nonmoral_ratio_test_rap)
plt.title('moral_nonmoral_ratio for rap Vs Year')
plt.xlabel('Year')
plt.ylabel('moral_nonmoral_ratio')
plt.show()
figure(figsize=(8, 100), dpi=800)

# %%
# line chart for moral_nonmoral_ratio for non rap
# result--> no pattern from line plot for moral_nonmoral_ratio, try scatter plot
year_test_non_rap=listby_not_rap.iloc[1:6236 :,4]
moral_nonmoral_ratio_test_non_rap=listby_not_rap.iloc[1:6236:,21]

plt.plot(year_test_non_rap, moral_nonmoral_ratio_test_non_rap)
plt.title('moral_nonmoral_ratio for non rap Vs Year')
plt.xlabel('Year')
plt.ylabel('moral_nonmoral_ratio')
plt.show()
figure(figsize=(8, 100), dpi=800)

# %%
# scatter plot for moral_nonmoral_ratio for rap
# result--> the distribution is not clearly showed, try box plot to see the distribution
year_test_rap=listby_rap.iloc[1:5432 :,4]
moral_nonmoral_ratio_test_rap=listby_rap.iloc[1:5432:,21]

plt.scatter(year_test_rap,moral_nonmoral_ratio_test_rap)
plt.title('moral_nonmoral_ratio for rap Vs Year')
plt.xlabel('Year')
plt.ylabel('moral_nonmoral_ratio')
plt.show()
figure(figsize=(8, 100), dpi=800)

# %%
# scatter plot for moral_nonmoral_ratio for non rap
# result--> 
year_test_non_rap=listby_not_rap.iloc[1:6236 :,4]
moral_nonmoral_ratio_test_non_rap=listby_not_rap.iloc[1:6236:,21]

plt.scatter(year_test_non_rap, moral_nonmoral_ratio_test_non_rap)
plt.title('moral_nonmoral_ratio for non rap Vs Year')
plt.xlabel('Year')
plt.ylabel('moral_nonmoral_ratio')
plt.show()
figure(figsize=(8, 100), dpi=800)

# %%
# boxplot rap moral_nonmoral_ratio
listby_rap.boxplot(by='year', column=['moral_nonmoral_ratio'], grid=False)
plt.title("boxplot rap moral_nonmoral_ratio")
figure(figsize=(8, 100), dpi=800)

# %%
# boxplot non_rap moral_nonmoral_ratio
listby_not_rap.boxplot(by='year', column=['moral_nonmoral_ratio'], grid=False)
plt.tile
figure(figsize=(8, 100), dpi=800)

# %%
# boxplot rap care_p

listby_rap.boxplot(by='year', column=['care_p'], grid=False)
figure(figsize=(30, 40), dpi=1200)

# %%
# boxplot rap care_p

listby_not_rap.boxplot(by='year', column=['care_p'], grid=False)
plt.title("boxplot not rap care_p")
figure(figsize=(30, 40), dpi=1200)

# %%
# for rap,mean for all samples "authority_sent", "sanctity_sent" and "moral_nonmoral_ratio" are comparatively lower than non_rap

# %%
# boxplot not rap authority_sent

listby_not_rap.boxplot(by='year', column=['authority_sent'], grid=False)
plt.title("boxplot not rap authority_sent")
figure(figsize=(30, 40), dpi=1200)

# %%
# boxplot rap authority_sent

listby_rap.boxplot(by='year', column=['authority_sent'], grid=False)
plt.title("boxplot rap authority_sent")
figure(figsize=(30, 40), dpi=1200)

# %%
# boxplot non rap authority_sent

listby_not_rap.boxplot(by='year', column=['sanctity_sent'], grid=False)
plt.title("boxplot not rap sanctity_sent")
figure(figsize=(30, 40), dpi=1200)

# %%
# boxplot  rap authority_sent
listby_rap.boxplot(by='year', column=['sanctity_sent'], grid=False)
plt.title("boxplot rap sanctity_sent")
figure(figsize=(30, 40), dpi=1200)

# %%
sns.violinplot(listby_rap['year'], listby_rap['sanctity_sent'], grid=False)
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='sanctity_sent'>

# %%
sns.violinplot(listby_rap['year'], listby_rap['care_p'], grid=False)
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='care_p'>

# %%
sns.violinplot(listby_rap['year'], listby_rap['fairness_p'], grid=False)
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='fairness_p'>

# %%
sns.violinplot(listby_rap['year'], listby_rap['loyalty_p'], grid=False)
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='loyalty_p'>

# %%
sns.violinplot(listby_not_rap.iloc[5600:,4], listby_not_rap['loyalty_p'], grid=False)
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='loyalty_p'>

# %% [markdown]
# # # 2014 blm, all issues very intense, authority_p very low, 2021 become lower

# %%
# 2014 blm, all issues very intense, authority_p very low, 2021 become lower
sns.violinplot(listby_rap['year'], listby_rap['authority_p'], grid=False)
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='authority_p'>

# %%
sns.violinplot(listby_rap.iloc[5100:,4], listby_rap['authority_p'], grid=False)
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='authority_p'>

# %%
#non rap can't tell such change
sns.violinplot(listby_not_rap.iloc[5700:,4], listby_not_rap['authority_p'], grid=False)
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='authority_p'>

# %%
sns.violinplot(listby_rap['year'], listby_rap['care_sent'], grid=False)
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='care_sent'>

# %%
sns.violinplot(listby_rap['year'], listby_rap['fairness_sent'], grid=False)
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='fairness_sent'>

# %%
sns.violinplot(listby_rap['year'], listby_rap['loyalty_sent'], grid=False)
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='loyalty_sent'>

# %%
sns.violinplot(listby_rap['year'], listby_rap['sanctity_sent'], grid=False)
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='sanctity_sent'>

# %%
sns.violinplot(listby_rap['year'], listby_rap['moral_nonmoral_ratio'], grid=False)
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='moral_nonmoral_ratio'>

# %%
sns.violinplot(listby_rap.iloc[5000:,4], listby_rap['fairness_sent'], grid=False)
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='fairness_sent'>

# %%
sns.violinplot(listby_rap['year'], listby_rap['f_var'], grid=False)
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='f_var'>

# %%
sns.violinplot(listby_rap['year'], listby_rap['sent_var'], grid=False)
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='sent_var'>

# %%
# regression plot not working
sns.regplot(listby_rap['year'], listby_rap['sanctity_sent'], ci=60)
cm = 1/2.54
figsize=(1550*cm, 50*cm)
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Profanity frequency Checker

# %%
import pandas as pd
import nltk
import re
import string
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import word_tokenize

stop_words = stopwords.words()
swear_words= pd.read_csv("bad-words.csv")
swearwords_list = swear_words['jigaboo'].values.tolist()



def cleaning(text):        
    # converting to lowercase, removing URL links, special characters, punctuations...
    text = text.lower()
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('[’“”…]', '', text)     

    # removing the stop-words          
    text_tokens = word_tokenize(text)
    tokens_without_sw = [word for word in text_tokens if not word in stop_words]
    filtered_sentence = (" ").join(tokens_without_sw)
    text = filtered_sentence
    
    # counts only the swear words
    tokens_with_swearword =[word for word in text_tokens if word in swearwords_list]
    filtered_onlyswearword_sentence = (" ").join(tokens_with_swearword)
    text = filtered_onlyswearword_sentence
    
    return text

dt = listby_not_rap["lyrics"].apply(cleaning)

from collections import Counter
p = Counter(" ".join(dt).split()).most_common(10)
rslt = pd.DataFrame(p, columns=['Word', 'Frequency'])
print(rslt)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\90746\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\90746\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#     Word  Frequency
# 0    god        857
# 1   shit        778
# 2   fire        698
# 3   fuck        632
# 4   hell        592
# 5    die        545
# 6  girls        478
# 7  fight        461
# 8  black        451
# 9   kill        418

# %%
import pandas as pd
import nltk
import re
import string
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import word_tokenize

stop_words = stopwords.words()
swear_words= pd.read_csv("bad-words.csv")
swearwords_list = swear_words['jigaboo'].values.tolist()



def cleaning(text):        
    # converting to lowercase, removing URL links, special characters, punctuations...
    text = text.lower()
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('[’“”…]', '', text)     

    # removing the stop-words          
    text_tokens = word_tokenize(text)
    tokens_without_sw = [word for word in text_tokens if not word in stop_words]
    filtered_sentence = (" ").join(tokens_without_sw)
    text = filtered_sentence
    
    # counts only the swear words
    tokens_with_swearword =[word for word in text_tokens if word in swearwords_list]
    filtered_onlyswearword_sentence = (" ").join(tokens_with_swearword)
    text = filtered_onlyswearword_sentence
    
    return text

dt = listby_rap["lyrics"].apply(cleaning)

from collections import Counter
p = Counter(" ".join(dt).split()).most_common(10)
rslt = pd.DataFrame(p, columns=['Word', 'Frequency'])
print(rslt)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\90746\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\90746\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#       Word  Frequency
# 0    nigga      11635
# 1     shit       8030
# 2     fuck       7297
# 3    bitch       6446
# 4      ass       2998
# 5  bitches       2550
# 6   fuckin       2242
# 7     hoes       1814
# 8      god       1720
# 9    black       1612
